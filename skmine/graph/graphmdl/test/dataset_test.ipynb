# %%
from skmine.graph.graphmdl.graph_mdl import GraphMDL
from skmine.graph.graphmdl import utils

# %%
mutag = utils.get_graph_from_file(r"C:\Users\adjedjem\Downloads\Datasets_GraphMDLplus\Mutag-positive.txt-aggregate-doubled")
ptc_fr = utils.get_graph_from_file(r"C:\Users\adjedjem\Downloads\Datasets_GraphMDLplus\PTC_FR-positive.txt-aggregate-doubled")

# %%
mdl = GraphMDL(debug=True)

# %%
mdl.fit(ptc_fr)
# Out:
# 2022-08-02 10:11:22,930 	 [INFO | code_table.py:110] > cover time...13.280357599258423
# 2022-08-02 10:11:22,946 	 [INFO | graph_mdl.py:66] >
#  initial CT
#
#  Pattern |usage |code_length |port_count |port_usage |port_code
# In|12.368779260041338|12.368779260041338
# P|9.561424337983734|9.561424337983734
# C|2.159325894412388|2.159325894412388
# O|4.529575471944394|4.529575471944394
# N|5.1593258944123885|5.1593258944123885
# S|8.046851165153976|8.046851165153976
# Na|9.198854258599026|9.198854258599026
# Br|7.011227255423254|7.011227255423254
# Cl|6.08337704117909|6.08337704117909
# F|10.368779260041338|10.368779260041338
# triple|9.783816759320182|9.783816759320182
# aromatic|1.8218848001537011|1.8218848001537011
# single|1.5776163714863194|1.5776163714863194
# double|4.169106915204973|4.169106915204973
#
# 2022-08-02 10:11:22,946 	 [INFO | graph_mdl.py:67] > GraphMDL+ run ...
# 2022-08-02 10:11:22,946 	 [INFO | graph_mdl.py:68] > Initial description length = 118816.1
# ...

# %%
mdl.fit(ptc_fr)
# Out:
# 2022-08-02 09:43:56,553 	 [INFO | code_table.py:110] > cover time...14.233421087265015
# 2022-08-02 09:43:56,569 	 [INFO | graph_mdl.py:66] >
#  initial CT
#
#  Pattern |usage |code_length |port_count |port_usage |port_code
# In|12.368779260041338|12.368779260041338
# P|9.561424337983734|9.561424337983734
# C|2.159325894412388|2.159325894412388
# O|4.529575471944394|4.529575471944394
# N|5.1593258944123885|5.1593258944123885
# S|8.046851165153976|8.046851165153976
# Na|9.198854258599026|9.198854258599026
# Br|7.011227255423254|7.011227255423254
# Cl|6.08337704117909|6.08337704117909
# F|10.368779260041338|10.368779260041338
# triple|9.783816759320182|9.783816759320182
# aromatic|1.8218848001537011|1.8218848001537011
# single|1.5776163714863194|1.5776163714863194
# double|4.169106915204973|4.169106915204973
#
# 2022-08-02 09:43:56,569 	 [INFO | graph_mdl.py:67] > GraphMDL+ run ...
# 2022-08-02 09:43:56,569 	 [INFO | graph_mdl.py:68] > Initial description length = 118816.1
# ...
